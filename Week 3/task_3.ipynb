# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Create a black color image (RGB/BGR)
image = np.zeros((512, 512, 3), np.uint8)
# (512, 512, 3): height × width × 3 color channels (BGR)
# np.uint8: 8-bit unsigned integer type (pixel values 0–255)

# Create a black & white (grayscale) image
image_bw = np.zeros((512, 512), np.uint8)
# Only 2D because grayscale has a single channel

# Display color image (convert BGR → RGB for matplotlib)
plt.imshow(image[..., ::-1])
plt.title("Black Color Image")

# Display grayscale image
plt.figure()
plt.imshow(image_bw, cmap='gray')
plt.title("Black & White Image")
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Create a black color image
image = np.zeros((512, 512, 3), np.uint8)

# Draw a diagonal line from top-left to bottom-right
cv2.line(image, (0, 0), (511, 511), (255, 127, 0), 5)
# (255, 127, 0) is the color in BGR (Blue, Green, Red)
# 5 is the thickness of the line in pixels

# Display using OpenCV window
cv2.imshow("Blue Line", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# Display using matplotlib
plt.imshow(image[..., ::-1])  # Convert BGR to RGB for matplotlib
plt.title("Diagonal Line")
plt.show()
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/ayzrixsiev/Main/CAU/DIP_CAU/.venv/lib/python3.14/site-packages/cv2/qt/plugins"
# QApplication: invalid style override 'kvantum' passed, ignoring it.
# 	Available styles: Windows, Fusion
# QFontDatabase: Cannot find font directory /home/ayzrixsiev/Main/CAU/DIP_CAU/.venv/lib/python3.14/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ayzrixsiev/Main/CAU/DIP_CAU/.venv/lib/python3.14/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ayzrixsiev/Main/CAU/DIP_CAU/.venv/lib/python3.14/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ayzrixsiev/Main/CAU/DIP_CAU/.venv/lib/python3.14/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ayzrixsiev/Main/CAU/DIP_CAU/.venv/lib/python3.14/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = np.zeros((512, 512, 3), np.uint8)
cv2.rectangle(image, (100, 100), (300, 250), (0, 0, 255), 5)

cv2.imshow("Rectangle", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

plt.imshow(image[..., ::-1])
plt.title("Rectangle")
plt.show()
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/ayzrixsiev/Main/CAU/DIP_CAU/.venv/lib/python3.14/site-packages/cv2/qt/plugins"
# QApplication: invalid style override 'kvantum' passed, ignoring it.
# 	Available styles: Windows, Fusion
# QFontDatabase: Cannot find font directory /home/ayzrixsiev/Main/CAU/DIP_CAU/.venv/lib/python3.14/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ayzrixsiev/Main/CAU/DIP_CAU/.venv/lib/python3.14/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ayzrixsiev/Main/CAU/DIP_CAU/.venv/lib/python3.14/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ayzrixsiev/Main/CAU/DIP_CAU/.venv/lib/python3.14/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/ayzrixsiev/Main/CAU/DIP_CAU/.venv/lib/python3.14/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("./car.jpg")

cv2.rectangle(img, (280, 270), (530, 400), (0, 255, 255), 5)

plt.imshow(img[..., ::-1])
plt.title("Image with Rectangle")
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = np.zeros((512, 512, 3), np.uint8)

cv2.circle(image, (350, 350), 100, (15, 75, 50), 7)

cv2.imshow("Circle", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

plt.imshow(image[..., ::-1])
plt.title("Circle")
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

ellipse = np.zeros((512, 512, 3), np.uint8)

cv2.ellipse(ellipse, (250, 250), (250, 100), 45, 90, 360, (255, 255, 255), -1)

cv2.imshow("Ellipse", ellipse)
cv2.waitKey(0)
cv2.destroyAllWindows()

plt.imshow(ellipse[..., ::-1])
plt.title("Ellipse")
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = np.zeros((512, 512, 3), np.uint8)

pts = np.array([[10, 50], [400, 50], [90, 200], [50, 500]], np.int32)

pts = pts.reshape((-1, 1, 2))

cv2.polylines(image, [pts], True, (0, 0, 255), 3)

cv2.imshow("Polygon", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

plt.imshow(image[..., ::-1])
plt.title("Polygon")
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = np.zeros((512, 512, 3), np.uint8)

cv2.putText(image, 'Hello World!', (75, 290), cv2.FONT_HERSHEY_COMPLEX, 2, (100, 170, 0), 3)

cv2.imshow("Hello World!", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

plt.imshow(image[..., ::-1])
plt.title("Hello World!")
plt.show()
